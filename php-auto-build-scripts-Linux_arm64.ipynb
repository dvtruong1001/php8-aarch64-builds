# %% [markdown]
# <a href="https://colab.research.google.com/github/TukangM/php-build-scripts-auto/blob/main/php-auto-build-scripts-Linux_arm64.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # php-auto-build-scripts
# Hi there this script will make php8 for Linux_arm64

# %% [markdown]
# # Update repo and install dependencies

# %%
## Update repo and install dependencies
# !sudo apt update
# !sudo apt install make autoconf automake libtool m4 wget gzip bzip2 bison g++ git cmake pkg-config re2c libtool-bin zip unzip
# Out:
# Ign:1 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:5 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:6 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:7 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:10 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:11 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [83.3 kB]
# Hit:12 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Hit:13 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:14 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [2,235 kB]
# Get:15 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [1,143 kB]
# Fetched 3,659 kB in 4s (987 kB/s)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 20 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# make is already the newest version (4.1-9.1ubuntu1).
# make set to manually installed.
# pkg-config is already the newest version (0.29.1-0ubuntu2).
# zip is already the newest version (3.0-11build1).
# bzip2 is already the newest version (1.0.6-8.1ubuntu0.2).
# cmake is already the newest version (3.10.2-1ubuntu2.18.04.2).
# g++ is already the newest version (4:7.4.0-1ubuntu2.3).
# g++ set to manually installed.
# git is already the newest version (1:2.17.1-1ubuntu0.13).
# gzip is already the newest version (1.6-5ubuntu1.2).
# unzip is already the newest version (6.0-21ubuntu1.2).
# wget is already the newest version (1.19.4-1ubuntu2.2).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following additional packages will be installed:
#   autotools-dev file libbison-dev libmagic-mgc libmagic1 libsigsegv2
# Suggested packages:
#   autoconf-archive gnu-standards autoconf-doc gettext bison-doc libtool-doc
#   gcj-jdk m4-doc
# The following NEW packages will be installed:
#   autoconf automake autotools-dev bison file libbison-dev libmagic-mgc
#   libmagic1 libsigsegv2 libtool libtool-bin m4 re2c
# 0 upgraded, 13 newly installed, 0 to remove and 20 not upgraded.
# Need to get 2,509 kB of archives.
# After this operation, 13.4 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic-mgc amd64 1:5.32-2ubuntu0.4 [184 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic1 amd64 1:5.32-2ubuntu0.4 [68.6 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 file amd64 1:5.32-2ubuntu0.4 [22.1 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsigsegv2 amd64 2.12-1 [14.7 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 m4 amd64 1.4.18-1 [197 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/main amd64 autoconf all 2.69-11 [322 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/main amd64 autotools-dev all 20180224.1 [39.6 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/main amd64 automake all 1:1.15.1-3ubuntu2 [509 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/main amd64 libbison-dev amd64 2:3.0.4.dfsg-1build1 [339 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic/main amd64 bison amd64 2:3.0.4.dfsg-1build1 [266 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtool all 2.4.6-2 [194 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtool-bin amd64 2.4.6-2 [79.5 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/main amd64 re2c amd64 1.0.1-1 [274 kB]
# Fetched 2,509 kB in 2s (1,360 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 13.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libmagic-mgc.
# (Reading database ... 124016 files and directories currently installed.)
# Preparing to unpack .../00-libmagic-mgc_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking libmagic-mgc (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package libmagic1:amd64.
# Preparing to unpack .../01-libmagic1_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking libmagic1:amd64 (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package file.
# Preparing to unpack .../02-file_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking file (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package libsigsegv2:amd64.
# Preparing to unpack .../03-libsigsegv2_2.12-1_amd64.deb ...
# Unpacking libsigsegv2:amd64 (2.12-1) ...
# Selecting previously unselected package m4.
# Preparing to unpack .../04-m4_1.4.18-1_amd64.deb ...
# Unpacking m4 (1.4.18-1) ...
# Selecting previously unselected package autoconf.
# Preparing to unpack .../05-autoconf_2.69-11_all.deb ...
# Unpacking autoconf (2.69-11) ...
# Selecting previously unselected package autotools-dev.
# Preparing to unpack .../06-autotools-dev_20180224.1_all.deb ...
# Unpacking autotools-dev (20180224.1) ...
# Selecting previously unselected package automake.
# Preparing to unpack .../07-automake_1%3a1.15.1-3ubuntu2_all.deb ...
# Unpacking automake (1:1.15.1-3ubuntu2) ...
# Selecting previously unselected package libbison-dev:amd64.
# Preparing to unpack .../08-libbison-dev_2%3a3.0.4.dfsg-1build1_amd64.deb ...
# Unpacking libbison-dev:amd64 (2:3.0.4.dfsg-1build1) ...
# Selecting previously unselected package bison.
# Preparing to unpack .../09-bison_2%3a3.0.4.dfsg-1build1_amd64.deb ...
# Unpacking bison (2:3.0.4.dfsg-1build1) ...
# Selecting previously unselected package libtool.
# Preparing to unpack .../10-libtool_2.4.6-2_all.deb ...
# Unpacking libtool (2.4.6-2) ...
# Selecting previously unselected package libtool-bin.
# Preparing to unpack .../11-libtool-bin_2.4.6-2_amd64.deb ...
# Unpacking libtool-bin (2.4.6-2) ...
# Selecting previously unselected package re2c.
# Preparing to unpack .../12-re2c_1.0.1-1_amd64.deb ...
# Unpacking re2c (1.0.1-1) ...
# Setting up libsigsegv2:amd64 (2.12-1) ...
# Setting up re2c (1.0.1-1) ...
# Setting up m4 (1.4.18-1) ...
# Setting up libmagic-mgc (1:5.32-2ubuntu0.4) ...
# Setting up libmagic1:amd64 (1:5.32-2ubuntu0.4) ...
# Setting up autotools-dev (20180224.1) ...
# Setting up libbison-dev:amd64 (2:3.0.4.dfsg-1build1) ...
# Setting up bison (2:3.0.4.dfsg-1build1) ...
# update-alternatives: using /usr/bin/bison.yacc to provide /usr/bin/yacc (yacc) in auto mode
# Setting up autoconf (2.69-11) ...
# Setting up file (1:5.32-2ubuntu0.4) ...
# Setting up automake (1:1.15.1-3ubuntu2) ...
# update-alternatives: using /usr/bin/automake-1.15 to provide /usr/bin/automake (automake) in auto mode
# Setting up libtool (2.4.6-2) ...
# Setting up libtool-bin (2.4.6-2) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.6) ...

# %% [markdown]
# #cloning compiler musl-cross-make

# %%
#cloning compiler musl-cross-make
# !git clone https://github.com/TukangM/musl-cross-make
# %cd musl-cross-make
# Out:
# Cloning into 'musl-cross-make'...
# remote: Enumerating objects: 1164, done.
# remote: Counting objects: 100% (50/50), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 1164 (delta 23), reused 26 (delta 17), pack-reused 1114
# Receiving objects: 100% (1164/1164), 311.75 KiB | 1.69 MiB/s, done.
# Resolving deltas: 100% (623/623), done.
# /content/musl-cross-make

# %% [markdown]
# #compiling musl-cross-make for php-build-scripts-auto
# it takes 30mins- 1+hours (if you get 2 more processor cores. maybe the process will be fast if you are lucky) so you wait and you standby here

# %%
#compiling musl-cross-make for php-build-scripts-auto #it takes 30mins- 1hours (if you get 2 more processor cores. maybe the process will be fast if you are lucky) so you wait and you standby here
# !make install
# Out:
# Streaming output truncated to the last 5000 lines.
# checking for sys/time.h... (cached) yes
# checking for sys/types.h... (cached) yes
# checking for unistd.h... (cached) yes
# checking for wchar.h... (cached) yes
# checking for wctype.h... (cached) yes
# checking linux/types.h usability... no
# checking linux/types.h presence... no
# checking for linux/types.h... no
# checking for linux/random.h... no
# checking for g++ that supports -ffunction-sections -fdata-sections... yes
# checking for ld version... 23301
# checking for ld that supports -Wl,--gc-sections... yes
# checking for ld that supports -Wl,-z,relro... yes
# checking for sin in -lm... (cached) yes
# checking for isinf declaration... yes
# checking for isinf... no
# checking for isnan declaration... yes
# checking for isnan... no
# checking for finite declaration... yes
# checking for finite... yes
# checking for sincos declaration... yes
# checking for sincos... yes
# checking for fpclass declaration... no
# checking for _fpclass declaration... no
# checking for qfpclass declaration... no
# checking for _qfpclass declaration... no
# checking for hypot declaration... yes
# checking for hypot... yes
# checking for float trig functions... yes
# checking for acosf... yes
# checking for asinf... yes
# checking for atanf... yes
# checking for cosf... yes
# checking for sinf... yes
# checking for tanf... yes
# checking for coshf... yes
# checking for sinhf... yes
# checking for tanhf... yes
# checking for float round functions... yes
# checking for ceilf... yes
# checking for floorf... yes
# checking for expf declaration... yes
# checking for expf... yes
# checking for isnanf declaration... no
# checking for _isnanf declaration... no
# checking for isinff declaration... no
# checking for _isinff declaration... no
# checking for atan2f declaration... yes
# checking for atan2f... yes
# checking for fabsf declaration... yes
# checking for fabsf... yes
# checking for fmodf declaration... yes
# checking for fmodf... yes
# checking for frexpf declaration... yes
# checking for frexpf... yes
# checking for hypotf declaration... yes
# checking for hypotf... yes
# checking for ldexpf declaration... yes
# checking for ldexpf... yes
# checking for logf declaration... yes
# checking for logf... yes
# checking for log10f declaration... yes
# checking for log10f... yes
# checking for modff declaration... yes
# checking for modff... yes
# checking for modf declaration... yes
# checking for modf... yes
# checking for powf declaration... yes
# checking for powf... yes
# checking for sqrtf declaration... yes
# checking for sqrtf... yes
# checking for sincosf declaration... yes
# checking for sincosf... yes
# checking for finitef declaration... yes
# checking for finitef... yes
# checking for long double trig functions... yes
# checking for acosl... yes
# checking for asinl... yes
# checking for atanl... yes
# checking for cosl... yes
# checking for sinl... yes
# checking for tanl... yes
# checking for coshl... yes
# checking for sinhl... yes
# checking for tanhl... yes
# checking for long double round functions... yes
# checking for ceill... yes
# checking for floorl... yes
# checking for isnanl declaration... no
# checking for _isnanl declaration... no
# checking for isinfl declaration... no
# checking for _isinfl declaration... no
# checking for atan2l declaration... yes
# checking for atan2l... yes
# checking for expl declaration... yes
# checking for expl... yes
# checking for fabsl declaration... yes
# checking for fabsl... yes
# checking for fmodl declaration... yes
# checking for fmodl... yes
# checking for frexpl declaration... yes
# checking for frexpl... yes
# checking for hypotl declaration... yes
# checking for hypotl... yes
# checking for ldexpl declaration... yes
# checking for ldexpl... yes
# checking for logl declaration... yes
# checking for logl... yes
# checking for log10l declaration... yes
# checking for log10l... yes
# checking for modfl declaration... yes
# checking for modfl... yes
# checking for powl declaration... yes
# checking for powl... yes
# checking for sqrtl declaration... yes
# checking for sqrtl... yes
# checking for sincosl declaration... yes
# checking for sincosl... yes
# checking for finitel declaration... no
# checking for _finitel declaration... no
# checking for at_quick_exit declaration... yes
# checking for at_quick_exit... yes
# checking for quick_exit declaration... yes
# checking for quick_exit... yes
# checking for strtold declaration... yes
# checking for strtold... yes
# checking for strtof declaration... yes
# checking for strtof... yes
# checking whether the target supports thread-local storage... yes
# checking for __cxa_thread_atexit_impl... no
# checking for aligned_alloc... yes
# checking for posix_memalign... yes
# checking for memalign... yes
# checking for _aligned_malloc... no
# checking for timespec_get... yes
# checking for sockatmark... yes
# checking for iconv... yes
# checking for iconv declaration...
#          extern size_t iconv (iconv_t cd, char * *inbuf, size_t *inbytesleft, char * *outbuf, size_t *outbytesleft);
# looking for a compliant stdint.h in stdint.h, checking for uintmax_t... yes
# checking for uintptr_t... yes
# checking for int_least32_t... yes
# checking for int_fast32_t... yes
# checking for uint64_t... yes
# checking what to include in include/gstdint.h... stdint.h (already complete)
# checking for GNU c++filt... /usr/bin/c++filt
# checking for shared libgcc... yes
# checking whether the target supports .symver directive... yes
# configure: versioning on shared library symbols is gnu
# checking for size_t as unsigned int... no
# checking for ptrdiff_t as int... no
# checking whether the target supports hidden visibility... yes
# configure: visibility supported: yes
# checking for default std::string ABI to use... new
# checking for rdrand support in assembler... no
# checking for unistd.h... (cached) yes
# checking for sys/time.h... (cached) yes
# checking for sys/resource.h... (cached) yes
# checking for RLIMIT_DATA... yes
# checking for RLIMIT_RSS... yes
# checking for RLIMIT_VMEM... no
# checking for RLIMIT_AS... yes
# checking for RLIMIT_FSIZE... yes
# checking for testsuite resource limits support... yes
# checking whether it can be safely assumed that mutex_timedlock is available... yes
# checking for gthreads library... yes
# checking for pthread_rwlock_t... yes
# checking fcntl.h usability... yes
# checking fcntl.h presence... yes
# checking for fcntl.h... yes
# checking dirent.h usability... yes
# checking dirent.h presence... yes
# checking for dirent.h... yes
# checking sys/statvfs.h usability... yes
# checking sys/statvfs.h presence... yes
# checking for sys/statvfs.h... yes
# checking utime.h usability... yes
# checking utime.h presence... yes
# checking for utime.h... yes
# checking whether to build Filesystem TS support... yes
# checking for struct dirent.d_type... yes
# checking for realpath... yes
# checking for utimensat... yes
# checking for utime... yes
# checking for lstat... yes
# checking for struct stat.st_mtim.tv_nsec... yes
# checking for fchmod... yes
# checking for fchmodat... yes
# checking for sendfile that can copy files... yes
# checking for link... yes
# checking for readlink... yes
# checking for symlink... yes
# checking for truncate... yes
# checking for fcntl.h... (cached) yes
# checking for sys/ioctl.h... (cached) yes
# checking sys/socket.h usability... yes
# checking sys/socket.h presence... yes
# checking for sys/socket.h... yes
# checking for sys/uio.h... (cached) yes
# checking poll.h usability... yes
# checking poll.h presence... yes
# checking for poll.h... yes
# checking netdb.h usability... yes
# checking netdb.h presence... yes
# checking for netdb.h... yes
# checking arpa/inet.h usability... yes
# checking arpa/inet.h presence... yes
# checking for arpa/inet.h... yes
# checking netinet/in.h usability... yes
# checking netinet/in.h presence... yes
# checking for netinet/in.h... yes
# checking netinet/tcp.h usability... yes
# checking netinet/tcp.h presence... yes
# checking for netinet/tcp.h... yes
# checking how size_t is mangled... m
# checking for first version to support std::exception_ptr... 4.6.0
# checking for makeinfo... false --split-size=5000000
# checking for modern makeinfo... no
# checking for doxygen... no
# checking for dot... yes
# checking for xmlcatalog... no
# checking for xsltproc... no
# checking for xmllint... no
# checking for local stylesheet directory... no
# checking for epub3 stylesheets for documentation creation... no
# checking for dblatex... no
# checking for pdflatex... no
# checking for CET support... no
# configure: updating cache ./config.cache
# checking for gxx-include-dir... no
# checking for --enable-version-specific-runtime-libs... no
# checking for install location... ${prefix}/${target_alias}/include/c++/${gcc_version}
# checking that generated files are newer than configure... done
# configure: creating ./config.status
# config.status: creating Makefile
# config.status: creating scripts/testsuite_flags
# config.status: creating scripts/extract_symvers
# config.status: creating doc/xsl/customization.xsl
# config.status: creating include/Makefile
# config.status: creating libsupc++/Makefile
# config.status: creating src/Makefile
# config.status: creating src/c++98/Makefile
# config.status: creating src/c++11/Makefile
# config.status: creating src/c++17/Makefile
# config.status: creating src/filesystem/Makefile
# config.status: creating doc/Makefile
# config.status: creating po/Makefile
# config.status: creating testsuite/Makefile
# config.status: creating python/Makefile
# config.status: creating config.h
# config.status: executing default-1 commands
# config.status: executing libtool commands
# config.status: executing include/gstdint.h commands
# config.status: executing generate-headers commands
# make[4]: Entering directory '/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/include'
# echo timestamp > stamp-pb
# echo timestamp > stamp-host
# Makefile:1771: recipe for target 'aarch64-linux-musl/bits/largefile-config.h' failed
# make[4]: [aarch64-linux-musl/bits/largefile-config.h] Error 1 (ignored)
# Makefile:1771: recipe for target 'aarch64-linux-musl/bits/largefile-config.h' failed
# make[4]: [aarch64-linux-musl/bits/largefile-config.h] Error 1 (ignored)
# echo 0 > stamp-namespace-version
# echo 1 > stamp-visibility
# echo 1 > stamp-extern-template
# echo 1 > stamp-dual-abi
# echo 1 > stamp-cxx11-abi
# echo 1 > stamp-allocator-new
# echo 'undef _GLIBCXX_USE_FLOAT128' > stamp-float128
# sed -e '/^#pragma/b' \
#     -e '/^#/s/\([ABCDEFGHIJKLMNOPQRSTUVWXYZ_][ABCDEFGHIJKLMNOPQRSTUVWXYZ_]*\)/_GLIBCXX_\1/g' \
#     -e 's/_GLIBCXX_SUPPORTS_WEAK/__GXX_WEAK__/g' \
#     -e 's/_GLIBCXX___MINGW32_GLIBCXX___/__MINGW32__/g' \
#     -e 's,^#include "\(.*\)",#include <bits/\1>,g' \
#     < /content/musl-cross-make/build/local/aarch64-linux-musl/src_gcc/libstdc++-v3/../libgcc/gthr.h > aarch64-linux-musl/bits/gthr.h
# sed -e 's/\(UNUSED\)/_GLIBCXX_\1/g' \
#     -e 's/\(GCC[ABCDEFGHIJKLMNOPQRSTUVWXYZ_]*_H\)/_GLIBCXX_\1/g' \
#     < /content/musl-cross-make/build/local/aarch64-linux-musl/src_gcc/libstdc++-v3/../libgcc/gthr-single.h > aarch64-linux-musl/bits/gthr-single.h
# sed -e 's/\(UNUSED\)/_GLIBCXX_\1/g' \
#     -e 's/\(GCC[ABCDEFGHIJKLMNOPQRSTUVWXYZ_]*_H\)/_GLIBCXX_\1/g' \
#     -e 's/SUPPORTS_WEAK/__GXX_WEAK__/g' \
#     -e 's/\([ABCDEFGHIJKLMNOPQRSTUVWXYZ_]*USE_WEAK\)/_GLIBCXX_\1/g' \
#     < /content/musl-cross-make/build/local/aarch64-linux-musl/src_gcc/libstdc++-v3/../libgcc/gthr-posix.h > aarch64-linux-musl/bits/gthr-posix.h
# sed -e 's/\(UNUSED\)/_GLIBCXX_\1/g' \
#     -e 's/\(GCC[ABCDEFGHIJKLMNOPQRSTUVWXYZ_]*_H\)/_GLIBCXX_\1/g' \
#     -e 's/SUPPORTS_WEAK/__GXX_WEAK__/g' \
#     -e 's/\([ABCDEFGHIJKLMNOPQRSTUVWXYZ_]*USE_WEAK\)/_GLIBCXX_\1/g' \
#     -e 's,^#include "\(.*\)",#include <bits/\1>,g' \
#     < /content/musl-cross-make/build/local/aarch64-linux-musl/src_gcc/libstdc++-v3/../libgcc/gthr-posix.h > aarch64-linux-musl/bits/gthr-default.h
# make[4]: Leaving directory '/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/include'
# make[4]: Entering directory '/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3'
# make MULTILIB_OSDIRNAMES= INFO_DEPS= infodir= ac_cv_prog_lex_root=lex.yy MAKEINFO=false  "AR_FLAGS=rc" "CC_FOR_BUILD=gcc" "CC_FOR_TARGET=/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/./gcc/xgcc -B/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/./gcc/" "CFLAGS=-g -O2" "CXXFLAGS=-g -O2 -D_GNU_SOURCE" "CFLAGS_FOR_BUILD=-g -O2" "CFLAGS_FOR_TARGET=-g -O2" "INSTALL=/usr/bin/install -c" "INSTALL_DATA=/usr/bin/install -c -m 644" "INSTALL_PROGRAM=/usr/bin/install -c" "INSTALL_SCRIPT=/usr/bin/install -c" "LDFLAGS=" "LIBCFLAGS=-g -O2" "LIBCFLAGS_FOR_TARGET=-g -O2" "MAKE=make MULTILIB_OSDIRNAMES= INFO_DEPS= infodir= ac_cv_prog_lex_root=lex.yy MAKEINFO=false " "MAKEINFO=false --split-size=5000000 --split-size=5000000 " "SHELL=/bin/bash" "RUNTESTFLAGS=" "exec_prefix=" "infodir=" "libdir=/lib" "includedir=/include" "prefix=" "tooldir=/aarch64-linux-musl" "gxx_include_dir=/aarch64-linux-musl/include/c++/9.4.0" "AR=/content/musl-cross-make/build/local/aarch64-linux-musl/obj_binutils/binutils/ar" "AS=/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/./gcc/as" "LD=/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/./gcc/collect-ld" "RANLIB=/content/musl-cross-make/build/local/aarch64-linux-musl/obj_binutils/binutils/ranlib" "NM=/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/./gcc/nm" "NM_FOR_BUILD=" "NM_FOR_TARGET=/content/musl-cross-make/build/local/aarch64-linux-musl/obj_binutils/binutils/nm-new" "DESTDIR=" "WERROR=" all-recursive
# make[5]: Entering directory '/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3'
# Making all in include
# make[6]: Entering directory '/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/include'
# mkdir -p ./aarch64-linux-musl/bits/stdc++.h.gch
# /content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/./gcc/xgcc -shared-libgcc -B/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/./gcc -nostdinc++ -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/src -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/src/.libs -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/libsupc++/.libs -B/aarch64-linux-musl/bin/ -B/aarch64-linux-musl/lib/ -isystem /aarch64-linux-musl/include -isystem /aarch64-linux-musl/sys-include --sysroot=/content/musl-cross-make/build/local/aarch64-linux-musl/obj_sysroot   -x c++-header -nostdinc++ -g -O2 -D_GNU_SOURCE  -I/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/include/aarch64-linux-musl -I/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/include -I/content/musl-cross-make/build/local/aarch64-linux-musl/src_gcc/libstdc++-v3/libsupc++  -O2 -g -std=gnu++0x /content/musl-cross-make/build/local/aarch64-linux-musl/src_gcc/libstdc++-v3/include/precompiled/stdc++.h \
# -o aarch64-linux-musl/bits/stdc++.h.gch/O2ggnu++0x.gch
# mkdir -p ./aarch64-linux-musl/bits/stdc++.h.gch
# /content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/./gcc/xgcc -shared-libgcc -B/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/./gcc -nostdinc++ -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/src -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/src/.libs -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/libsupc++/.libs -B/aarch64-linux-musl/bin/ -B/aarch64-linux-musl/lib/ -isystem /aarch64-linux-musl/include -isystem /aarch64-linux-musl/sys-include --sysroot=/content/musl-cross-make/build/local/aarch64-linux-musl/obj_sysroot   -x c++-header -nostdinc++ -g -O2 -D_GNU_SOURCE  -I/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/include/aarch64-linux-musl -I/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/include -I/content/musl-cross-make/build/local/aarch64-linux-musl/src_gcc/libstdc++-v3/libsupc++  -O2 -g /content/musl-cross-make/build/local/aarch64-linux-musl/src_gcc/libstdc++-v3/include/precompiled/stdc++.h -o aarch64-linux-musl/bits/stdc++.h.gch/O2g.gch
# mkdir -p ./aarch64-linux-musl/bits/stdtr1c++.h.gch
# /content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/./gcc/xgcc -shared-libgcc -B/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/./gcc -nostdinc++ -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/src -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/src/.libs -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/libsupc++/.libs -B/aarch64-linux-musl/bin/ -B/aarch64-linux-musl/lib/ -isystem /aarch64-linux-musl/include -isystem /aarch64-linux-musl/sys-include --sysroot=/content/musl-cross-make/build/local/aarch64-linux-musl/obj_sysroot   -x c++-header -nostdinc++ -g -O2 -D_GNU_SOURCE  -I/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/include/aarch64-linux-musl -I/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/include -I/content/musl-cross-make/build/local/aarch64-linux-musl/src_gcc/libstdc++-v3/libsupc++  -O2 -g /content/musl-cross-make/build/local/aarch64-linux-musl/src_gcc/libstdc++-v3/include/precompiled/stdtr1c++.h -o aarch64-linux-musl/bits/stdtr1c++.h.gch/O2g.gch
# mkdir -p ./aarch64-linux-musl/bits/extc++.h.gch
# /content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/./gcc/xgcc -shared-libgcc -B/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/./gcc -nostdinc++ -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/src -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/src/.libs -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/libsupc++/.libs -B/aarch64-linux-musl/bin/ -B/aarch64-linux-musl/lib/ -isystem /aarch64-linux-musl/include -isystem /aarch64-linux-musl/sys-include --sysroot=/content/musl-cross-make/build/local/aarch64-linux-musl/obj_sysroot   -x c++-header -nostdinc++ -g -O2 -D_GNU_SOURCE  -I/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/include/aarch64-linux-musl -I/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/include -I/content/musl-cross-make/build/local/aarch64-linux-musl/src_gcc/libstdc++-v3/libsupc++  -O2 -g /content/musl-cross-make/build/local/aarch64-linux-musl/src_gcc/libstdc++-v3/include/precompiled/extc++.h -o aarch64-linux-musl/bits/extc++.h.gch/O2g.gch
# make[6]: Leaving directory '/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/include'
# Making all in libsupc++
# make[6]: Entering directory '/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/libsupc++'
# /bin/bash ../libtool --tag CXX --tag disable-shared   --mode=compile /content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/./gcc/xgcc -shared-libgcc -B/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/./gcc -nostdinc++ -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/src -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/src/.libs -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/libsupc++/.libs -B/aarch64-linux-musl/bin/ -B/aarch64-linux-musl/lib/ -isystem /aarch64-linux-musl/include -isystem /aarch64-linux-musl/sys-include --sysroot=/content/musl-cross-make/build/local/aarch64-linux-musl/obj_sysroot   -I/content/musl-cross-make/build/local/aarch64-linux-musl/src_gcc/libstdc++-v3/../libgcc -I/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/include/aarch64-linux-musl -I/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/include -I/content/musl-cross-make/build/local/aarch64-linux-musl/src_gcc/libstdc++-v3/libsupc++   -prefer-pic -D_GLIBCXX_SHARED -fno-implicit-templates -Wall -Wextra -Wwrite-strings -Wcast-qual -Wabi=2  -fdiagnostics-show-location=once    -ffunction-sections -fdata-sections  -frandom-seed=array_type_info.lo -g -O2 -D_GNU_SOURCE  -c -o array_type_info.lo ../../../../src_gcc/libstdc++-v3/libsupc++/array_type_info.cc
# libtool: compile:  /content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/./gcc/xgcc -shared-libgcc -B/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/./gcc -nostdinc++ -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/src -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/src/.libs -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/libsupc++/.libs -B/aarch64-linux-musl/bin/ -B/aarch64-linux-musl/lib/ -isystem /aarch64-linux-musl/include -isystem /aarch64-linux-musl/sys-include --sysroot=/content/musl-cross-make/build/local/aarch64-linux-musl/obj_sysroot -I/content/musl-cross-make/build/local/aarch64-linux-musl/src_gcc/libstdc++-v3/../libgcc -I/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/include/aarch64-linux-musl -I/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/include -I/content/musl-cross-make/build/local/aarch64-linux-musl/src_gcc/libstdc++-v3/libsupc++ -D_GLIBCXX_SHARED -fno-implicit-templates -Wall -Wextra -Wwrite-strings -Wcast-qual -Wabi=2 -fdiagnostics-show-location=once -ffunction-sections -fdata-sections -frandom-seed=array_type_info.lo -g -O2 -D_GNU_SOURCE -c ../../../../src_gcc/libstdc++-v3/libsupc++/array_type_info.cc  -fPIC -DPIC -D_GLIBCXX_SHARED -o array_type_info.o
# /bin/bash ../libtool --tag CXX --tag disable-shared   --mode=compile /content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/./gcc/xgcc -shared-libgcc -B/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/./gcc -nostdinc++ -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/src -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/src/.libs -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/libsupc++/.libs -B/aarch64-linux-musl/bin/ -B/aarch64-linux-musl/lib/ -isystem /aarch64-linux-musl/include -isystem /aarch64-linux-musl/sys-include --sysroot=/content/musl-cross-make/build/local/aarch64-linux-musl/obj_sysroot   -I/content/musl-cross-make/build/local/aarch64-linux-musl/src_gcc/libstdc++-v3/../libgcc -I/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/include/aarch64-linux-musl -I/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/include -I/content/musl-cross-make/build/local/aarch64-linux-musl/src_gcc/libstdc++-v3/libsupc++   -prefer-pic -D_GLIBCXX_SHARED -fno-implicit-templates -Wall -Wextra -Wwrite-strings -Wcast-qual -Wabi=2  -fdiagnostics-show-location=once    -ffunction-sections -fdata-sections  -frandom-seed=atexit_arm.lo -g -O2 -D_GNU_SOURCE  -c -o atexit_arm.lo ../../../../src_gcc/libstdc++-v3/libsupc++/atexit_arm.cc
# libtool: compile:  /content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/./gcc/xgcc -shared-libgcc -B/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/./gcc -nostdinc++ -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/src -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/src/.libs -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/libsupc++/.libs -B/aarch64-linux-musl/bin/ -B/aarch64-linux-musl/lib/ -isystem /aarch64-linux-musl/include -isystem /aarch64-linux-musl/sys-include --sysroot=/content/musl-cross-make/build/local/aarch64-linux-musl/obj_sysroot -I/content/musl-cross-make/build/local/aarch64-linux-musl/src_gcc/libstdc++-v3/../libgcc -I/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/include/aarch64-linux-musl -I/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/include -I/content/musl-cross-make/build/local/aarch64-linux-musl/src_gcc/libstdc++-v3/libsupc++ -D_GLIBCXX_SHARED -fno-implicit-templates -Wall -Wextra -Wwrite-strings -Wcast-qual -Wabi=2 -fdiagnostics-show-location=once -ffunction-sections -fdata-sections -frandom-seed=atexit_arm.lo -g -O2 -D_GNU_SOURCE -c ../../../../src_gcc/libstdc++-v3/libsupc++/atexit_arm.cc  -fPIC -DPIC -D_GLIBCXX_SHARED -o atexit_arm.o
# /bin/bash ../libtool --tag CXX --tag disable-shared   --mode=compile /content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/./gcc/xgcc -shared-libgcc -B/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/./gcc -nostdinc++ -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/src -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/src/.libs -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/libsupc++/.libs -B/aarch64-linux-musl/bin/ -B/aarch64-linux-musl/lib/ -isystem /aarch64-linux-musl/include -isystem /aarch64-linux-musl/sys-include --sysroot=/content/musl-cross-make/build/local/aarch64-linux-musl/obj_sysroot   -I/content/musl-cross-make/build/local/aarch64-linux-musl/src_gcc/libstdc++-v3/../libgcc -I/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/include/aarch64-linux-musl -I/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/include -I/content/musl-cross-make/build/local/aarch64-linux-musl/src_gcc/libstdc++-v3/libsupc++   -prefer-pic -D_GLIBCXX_SHARED -fno-implicit-templates -Wall -Wextra -Wwrite-strings -Wcast-qual -Wabi=2  -fdiagnostics-show-location=once    -ffunction-sections -fdata-sections  -frandom-seed=atexit_thread.lo -g -O2 -D_GNU_SOURCE  -c -o atexit_thread.lo ../../../../src_gcc/libstdc++-v3/libsupc++/atexit_thread.cc
# libtool: compile:  /content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/./gcc/xgcc -shared-libgcc -B/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/./gcc -nostdinc++ -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/src -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/src/.libs -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/libsupc++/.libs -B/aarch64-linux-musl/bin/ -B/aarch64-linux-musl/lib/ -isystem /aarch64-linux-musl/include -isystem /aarch64-linux-musl/sys-include --sysroot=/content/musl-cross-make/build/local/aarch64-linux-musl/obj_sysroot -I/content/musl-cross-make/build/local/aarch64-linux-musl/src_gcc/libstdc++-v3/../libgcc -I/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/include/aarch64-linux-musl -I/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/include -I/content/musl-cross-make/build/local/aarch64-linux-musl/src_gcc/libstdc++-v3/libsupc++ -D_GLIBCXX_SHARED -fno-implicit-templates -Wall -Wextra -Wwrite-strings -Wcast-qual -Wabi=2 -fdiagnostics-show-location=once -ffunction-sections -fdata-sections -frandom-seed=atexit_thread.lo -g -O2 -D_GNU_SOURCE -c ../../../../src_gcc/libstdc++-v3/libsupc++/atexit_thread.cc  -fPIC -DPIC -D_GLIBCXX_SHARED -o atexit_thread.o
# /bin/bash ../libtool --tag CXX --tag disable-shared   --mode=compile /content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/./gcc/xgcc -shared-libgcc -B/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/./gcc -nostdinc++ -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/src -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/src/.libs -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/libsupc++/.libs -B/aarch64-linux-musl/bin/ -B/aarch64-linux-musl/lib/ -isystem /aarch64-linux-musl/include -isystem /aarch64-linux-musl/sys-include --sysroot=/content/musl-cross-make/build/local/aarch64-linux-musl/obj_sysroot   -I/content/musl-cross-make/build/local/aarch64-linux-musl/src_gcc/libstdc++-v3/../libgcc -I/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/include/aarch64-linux-musl -I/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/include -I/content/musl-cross-make/build/local/aarch64-linux-musl/src_gcc/libstdc++-v3/libsupc++   -prefer-pic -D_GLIBCXX_SHARED -fno-implicit-templates -Wall -Wextra -Wwrite-strings -Wcast-qual -Wabi=2  -fdiagnostics-show-location=once    -ffunction-sections -fdata-sections  -frandom-seed=bad_alloc.lo -g -O2 -D_GNU_SOURCE  -c -o bad_alloc.lo ../../../../src_gcc/libstdc++-v3/libsupc++/bad_alloc.cc
# libtool: compile:  /content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/./gcc/xgcc -shared-libgcc -B/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/./gcc -nostdinc++ -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/src -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/src/.libs -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/libsupc++/.libs -B/aarch64-linux-musl/bin/ -B/aarch64-linux-musl/lib/ -isystem /aarch64-linux-musl/include -isystem /aarch64-linux-musl/sys-include --sysroot=/content/musl-cross-make/build/local/aarch64-linux-musl/obj_sysroot -I/content/musl-cross-make/build/local/aarch64-linux-musl/src_gcc/libstdc++-v3/../libgcc -I/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/include/aarch64-linux-musl -I/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/include -I/content/musl-cross-make/build/local/aarch64-linux-musl/src_gcc/libstdc++-v3/libsupc++ -D_GLIBCXX_SHARED -fno-implicit-templates -Wall -Wextra -Wwrite-strings -Wcast-qual -Wabi=2 -fdiagnostics-show-location=once -ffunction-sections -fdata-sections -frandom-seed=bad_alloc.lo -g -O2 -D_GNU_SOURCE -c ../../../../src_gcc/libstdc++-v3/libsupc++/bad_alloc.cc  -fPIC -DPIC -D_GLIBCXX_SHARED -o bad_alloc.o
# /bin/bash ../libtool --tag CXX --tag disable-shared   --mode=compile /content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/./gcc/xgcc -shared-libgcc -B/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/./gcc -nostdinc++ -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/src -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/src/.libs -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/libsupc++/.libs -B/aarch64-linux-musl/bin/ -B/aarch64-linux-musl/lib/ -isystem /aarch64-linux-musl/include -isystem /aarch64-linux-musl/sys-include --sysroot=/content/musl-cross-make/build/local/aarch64-linux-musl/obj_sysroot   -I/content/musl-cross-make/build/local/aarch64-linux-musl/src_gcc/libstdc++-v3/../libgcc -I/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/include/aarch64-linux-musl -I/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/include -I/content/musl-cross-make/build/local/aarch64-linux-musl/src_gcc/libstdc++-v3/libsupc++   -prefer-pic -D_GLIBCXX_SHARED -fno-implicit-templates -Wall -Wextra -Wwrite-strings -Wcast-qual -Wabi=2  -fdiagnostics-show-location=once    -ffunction-sections -fdata-sections  -frandom-seed=bad_array_length.lo -g -O2 -D_GNU_SOURCE  -c -o bad_array_length.lo ../../../../src_gcc/libstdc++-v3/libsupc++/bad_array_length.cc
# libtool: compile:  /content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/./gcc/xgcc -shared-libgcc -B/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/./gcc -nostdinc++ -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/src -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/src/.libs -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/libsupc++/.libs -B/aarch64-linux-musl/bin/ -B/aarch64-linux-musl/lib/ -isystem /aarch64-linux-musl/include -isystem /aarch64-linux-musl/sys-include --sysroot=/content/musl-cross-make/build/local/aarch64-linux-musl/obj_sysroot -I/content/musl-cross-make/build/local/aarch64-linux-musl/src_gcc/libstdc++-v3/../libgcc -I/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/include/aarch64-linux-musl -I/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/include -I/content/musl-cross-make/build/local/aarch64-linux-musl/src_gcc/libstdc++-v3/libsupc++ -D_GLIBCXX_SHARED -fno-implicit-templates -Wall -Wextra -Wwrite-strings -Wcast-qual -Wabi=2 -fdiagnostics-show-location=once -ffunction-sections -fdata-sections -frandom-seed=bad_array_length.lo -g -O2 -D_GNU_SOURCE -c ../../../../src_gcc/libstdc++-v3/libsupc++/bad_array_length.cc  -fPIC -DPIC -D_GLIBCXX_SHARED -o bad_array_length.o
# /bin/bash ../libtool --tag CXX --tag disable-shared   --mode=compile /content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/./gcc/xgcc -shared-libgcc -B/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/./gcc -nostdinc++ -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/src -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/src/.libs -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/libsupc++/.libs -B/aarch64-linux-musl/bin/ -B/aarch64-linux-musl/lib/ -isystem /aarch64-linux-musl/include -isystem /aarch64-linux-musl/sys-include --sysroot=/content/musl-cross-make/build/local/aarch64-linux-musl/obj_sysroot   -I/content/musl-cross-make/build/local/aarch64-linux-musl/src_gcc/libstdc++-v3/../libgcc -I/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/include/aarch64-linux-musl -I/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/include -I/content/musl-cross-make/build/local/aarch64-linux-musl/src_gcc/libstdc++-v3/libsupc++   -prefer-pic -D_GLIBCXX_SHARED -fno-implicit-templates -Wall -Wextra -Wwrite-strings -Wcast-qual -Wabi=2  -fdiagnostics-show-location=once    -ffunction-sections -fdata-sections  -frandom-seed=bad_array_new.lo -g -O2 -D_GNU_SOURCE  -c -o bad_array_new.lo ../../../../src_gcc/libstdc++-v3/libsupc++/bad_array_new.cc
# libtool: compile:  /content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/./gcc/xgcc -shared-libgcc -B/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/./gcc -nostdinc++ -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/src -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/src/.libs -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/libsupc++/.libs -B/aarch64-linux-musl/bin/ -B/aarch64-linux-musl/lib/ -isystem /aarch64-linux-musl/include -isystem /aarch64-linux-musl/sys-include --sysroot=/content/musl-cross-make/build/local/aarch64-linux-musl/obj_sysroot -I/content/musl-cross-make/build/local/aarch64-linux-musl/src_gcc/libstdc++-v3/../libgcc -I/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/include/aarch64-linux-musl -I/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/include -I/content/musl-cross-make/build/local/aarch64-linux-musl/src_gcc/libstdc++-v3/libsupc++ -D_GLIBCXX_SHARED -fno-implicit-templates -Wall -Wextra -Wwrite-strings -Wcast-qual -Wabi=2 -fdiagnostics-show-location=once -ffunction-sections -fdata-sections -frandom-seed=bad_array_new.lo -g -O2 -D_GNU_SOURCE -c ../../../../src_gcc/libstdc++-v3/libsupc++/bad_array_new.cc  -fPIC -DPIC -D_GLIBCXX_SHARED -o bad_array_new.o
# /bin/bash ../libtool --tag CXX --tag disable-shared   --mode=compile /content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/./gcc/xgcc -shared-libgcc -B/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/./gcc -nostdinc++ -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/src -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/src/.libs -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/libsupc++/.libs -B/aarch64-linux-musl/bin/ -B/aarch64-linux-musl/lib/ -isystem /aarch64-linux-musl/include -isystem /aarch64-linux-musl/sys-include --sysroot=/content/musl-cross-make/build/local/aarch64-linux-musl/obj_sysroot   -I/content/musl-cross-make/build/local/aarch64-linux-musl/src_gcc/libstdc++-v3/../libgcc -I/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/include/aarch64-linux-musl -I/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/include -I/content/musl-cross-make/build/local/aarch64-linux-musl/src_gcc/libstdc++-v3/libsupc++   -prefer-pic -D_GLIBCXX_SHARED -fno-implicit-templates -Wall -Wextra -Wwrite-strings -Wcast-qual -Wabi=2  -fdiagnostics-show-location=once    -ffunction-sections -fdata-sections  -frandom-seed=bad_cast.lo -g -O2 -D_GNU_SOURCE  -c -o bad_cast.lo ../../../../src_gcc/libstdc++-v3/libsupc++/bad_cast.cc
# libtool: compile:  /content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/./gcc/xgcc -shared-libgcc -B/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/./gcc -nostdinc++ -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/src -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/src/.libs -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/libsupc++/.libs -B/aarch64-linux-musl/bin/ -B/aarch64-linux-musl/lib/ -isystem /aarch64-linux-musl/include -isystem /aarch64-linux-musl/sys-include --sysroot=/content/musl-cross-make/build/local/aarch64-linux-musl/obj_sysroot -I/content/musl-cross-make/build/local/aarch64-linux-musl/src_gcc/libstdc++-v3/../libgcc -I/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/include/aarch64-linux-musl -I/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/include -I/content/musl-cross-make/build/local/aarch64-linux-musl/src_gcc/libstdc++-v3/libsupc++ -D_GLIBCXX_SHARED -fno-implicit-templates -Wall -Wextra -Wwrite-strings -Wcast-qual -Wabi=2 -fdiagnostics-show-location=once -ffunction-sections -fdata-sections -frandom-seed=bad_cast.lo -g -O2 -D_GNU_SOURCE -c ../../../../src_gcc/libstdc++-v3/libsupc++/bad_cast.cc  -fPIC -DPIC -D_GLIBCXX_SHARED -o bad_cast.o
# /bin/bash ../libtool --tag CXX --tag disable-shared   --mode=compile /content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/./gcc/xgcc -shared-libgcc -B/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/./gcc -nostdinc++ -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/src -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/src/.libs -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/libsupc++/.libs -B/aarch64-linux-musl/bin/ -B/aarch64-linux-musl/lib/ -isystem /aarch64-linux-musl/include -isystem /aarch64-linux-musl/sys-include --sysroot=/content/musl-cross-make/build/local/aarch64-linux-musl/obj_sysroot   -I/content/musl-cross-make/build/local/aarch64-linux-musl/src_gcc/libstdc++-v3/../libgcc -I/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/include/aarch64-linux-musl -I/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/include -I/content/musl-cross-make/build/local/aarch64-linux-musl/src_gcc/libstdc++-v3/libsupc++   -prefer-pic -D_GLIBCXX_SHARED -fno-implicit-templates -Wall -Wextra -Wwrite-strings -Wcast-qual -Wabi=2  -fdiagnostics-show-location=once    -ffunction-sections -fdata-sections  -frandom-seed=bad_typeid.lo -g -O2 -D_GNU_SOURCE  -c -o bad_typeid.lo ../../../../src_gcc/libstdc++-v3/libsupc++/bad_typeid.cc
# libtool: compile:  /content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/./gcc/xgcc -shared-libgcc -B/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/./gcc -nostdinc++ -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/src -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/src/.libs -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/libsupc++/.libs -B/aarch64-linux-musl/bin/ -B/aarch64-linux-musl/lib/ -isystem /aarch64-linux-musl/include -isystem /aarch64-linux-musl/sys-include --sysroot=/content/musl-cross-make/build/local/aarch64-linux-musl/obj_sysroot -I/content/musl-cross-make/build/local/aarch64-linux-musl/src_gcc/libstdc++-v3/../libgcc -I/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/include/aarch64-linux-musl -I/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/include -I/content/musl-cross-make/build/local/aarch64-linux-musl/src_gcc/libstdc++-v3/libsupc++ -D_GLIBCXX_SHARED -fno-implicit-templates -Wall -Wextra -Wwrite-strings -Wcast-qual -Wabi=2 -fdiagnostics-show-location=once -ffunction-sections -fdata-sections -frandom-seed=bad_typeid.lo -g -O2 -D_GNU_SOURCE -c ../../../../src_gcc/libstdc++-v3/libsupc++/bad_typeid.cc  -fPIC -DPIC -D_GLIBCXX_SHARED -o bad_typeid.o
# /bin/bash ../libtool --tag CXX --tag disable-shared   --mode=compile /content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/./gcc/xgcc -shared-libgcc -B/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/./gcc -nostdinc++ -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/src -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/src/.libs -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/libsupc++/.libs -B/aarch64-linux-musl/bin/ -B/aarch64-linux-musl/lib/ -isystem /aarch64-linux-musl/include -isystem /aarch64-linux-musl/sys-include --sysroot=/content/musl-cross-make/build/local/aarch64-linux-musl/obj_sysroot   -I/content/musl-cross-make/build/local/aarch64-linux-musl/src_gcc/libstdc++-v3/../libgcc -I/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/include/aarch64-linux-musl -I/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/include -I/content/musl-cross-make/build/local/aarch64-linux-musl/src_gcc/libstdc++-v3/libsupc++   -prefer-pic -D_GLIBCXX_SHARED -fno-implicit-templates -Wall -Wextra -Wwrite-strings -Wcast-qual -Wabi=2  -fdiagnostics-show-location=once    -ffunction-sections -fdata-sections  -frandom-seed=class_type_info.lo -g -O2 -D_GNU_SOURCE  -c -o class_type_info.lo ../../../../src_gcc/libstdc++-v3/libsupc++/class_type_info.cc
# libtool: compile:  /content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/./gcc/xgcc -shared-libgcc -B/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/./gcc -nostdinc++ -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/src -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/src/.libs -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/libsupc++/.libs -B/aarch64-linux-musl/bin/ -B/aarch64-linux-musl/lib/ -isystem /aarch64-linux-musl/include -isystem /aarch64-linux-musl/sys-include --sysroot=/content/musl-cross-make/build/local/aarch64-linux-musl/obj_sysroot -I/content/musl-cross-make/build/local/aarch64-linux-musl/src_gcc/libstdc++-v3/../libgcc -I/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/include/aarch64-linux-musl -I/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/include -I/content/musl-cross-make/build/local/aarch64-linux-musl/src_gcc/libstdc++-v3/libsupc++ -D_GLIBCXX_SHARED -fno-implicit-templates -Wall -Wextra -Wwrite-strings -Wcast-qual -Wabi=2 -fdiagnostics-show-location=once -ffunction-sections -fdata-sections -frandom-seed=class_type_info.lo -g -O2 -D_GNU_SOURCE -c ../../../../src_gcc/libstdc++-v3/libsupc++/class_type_info.cc  -fPIC -DPIC -D_GLIBCXX_SHARED -o class_type_info.o
# /bin/bash ../libtool --tag CXX --tag disable-shared   --mode=compile /content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/./gcc/xgcc -shared-libgcc -B/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/./gcc -nostdinc++ -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/src -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/src/.libs -L/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/libsupc++/.libs -B/aarch64-linux-musl/bin/ -B/aarch64-linux-musl/lib/ -isystem /aarch64-linux-musl/include -isystem /aarch64-linux-musl/sys-include --sysroot=/content/musl-cross-make/build/local/aarch64-linux-musl/obj_sysroot   -I/content/musl-cross-make/build/local/aarch64-linux-musl/src_gcc/libstdc++-v3/../libgcc -I/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/include/aarch64-linux-musl -I/content/musl-cross-make/build/local/aarch64-linux-musl/obj_gcc/aarch64-linux-musl/libstdc++-v3/include -I/content/musl-cross-make/build/local/aarch64-linux-musl/src_gcc/libstdc++-v3/libsupc++   -prefer-pic -D_GLIBCXX_SHARED -fno-implicit-templates -Wall -Wextra -Wwrite-strings -Wcast-qual -Wabi=2  -fdiagnostics-show-location=once    -ffunction-sections -fdata-sections  -frandom-seed=del_op.lo -g -O2 -D_GNU_SOURCE  -c -o del_op.lo ../../../../src_gcc/libstdc++-v3/libsupc++/del_op.cc
# ...
# tools/install.sh -D -m 644 arm64/include/linux/virtio_gpu.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/linux/virtio_gpu.h
# tools/install.sh -D -m 644 arm64/include/linux/virtio_ids.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/linux/virtio_ids.h
# tools/install.sh -D -m 644 arm64/include/linux/virtio_input.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/linux/virtio_input.h
# tools/install.sh -D -m 644 arm64/include/linux/virtio_mmio.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/linux/virtio_mmio.h
# tools/install.sh -D -m 644 arm64/include/linux/virtio_net.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/linux/virtio_net.h
# tools/install.sh -D -m 644 arm64/include/linux/virtio_pci.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/linux/virtio_pci.h
# tools/install.sh -D -m 644 arm64/include/linux/virtio_ring.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/linux/virtio_ring.h
# tools/install.sh -D -m 644 arm64/include/linux/virtio_rng.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/linux/virtio_rng.h
# tools/install.sh -D -m 644 arm64/include/linux/virtio_scsi.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/linux/virtio_scsi.h
# tools/install.sh -D -m 644 arm64/include/linux/virtio_types.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/linux/virtio_types.h
# tools/install.sh -D -m 644 arm64/include/linux/virtio_vsock.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/linux/virtio_vsock.h
# tools/install.sh -D -m 644 arm64/include/linux/vm_sockets.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/linux/vm_sockets.h
# tools/install.sh -D -m 644 arm64/include/linux/vm_sockets_diag.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/linux/vm_sockets_diag.h
# tools/install.sh -D -m 644 arm64/include/linux/vmcore.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/linux/vmcore.h
# tools/install.sh -D -m 644 arm64/include/linux/vsockmon.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/linux/vsockmon.h
# tools/install.sh -D -m 644 arm64/include/linux/vt.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/linux/vt.h
# tools/install.sh -D -m 644 arm64/include/linux/vtpm_proxy.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/linux/vtpm_proxy.h
# tools/install.sh -D -m 644 arm64/include/linux/wait.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/linux/wait.h
# tools/install.sh -D -m 644 arm64/include/linux/wanrouter.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/linux/wanrouter.h
# tools/install.sh -D -m 644 arm64/include/linux/watchdog.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/linux/watchdog.h
# tools/install.sh -D -m 644 arm64/include/linux/wimax.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/linux/wimax.h
# tools/install.sh -D -m 644 arm64/include/linux/wimax/i2400m.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/linux/wimax/i2400m.h
# tools/install.sh -D -m 644 arm64/include/linux/wireless.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/linux/wireless.h
# tools/install.sh -D -m 644 arm64/include/linux/wmi.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/linux/wmi.h
# tools/install.sh -D -m 644 arm64/include/linux/x25.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/linux/x25.h
# tools/install.sh -D -m 644 arm64/include/linux/xattr.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/linux/xattr.h
# tools/install.sh -D -m 644 arm64/include/linux/xfrm.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/linux/xfrm.h
# tools/install.sh -D -m 644 arm64/include/linux/xilinx-v4l2-controls.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/linux/xilinx-v4l2-controls.h
# tools/install.sh -D -m 644 arm64/include/linux/zorro.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/linux/zorro.h
# tools/install.sh -D -m 644 arm64/include/linux/zorro_ids.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/linux/zorro_ids.h
# tools/install.sh -D -m 644 arm64/include/mtd/inftl-user.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/mtd/inftl-user.h
# tools/install.sh -D -m 644 arm64/include/mtd/mtd-abi.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/mtd/mtd-abi.h
# tools/install.sh -D -m 644 arm64/include/mtd/mtd-user.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/mtd/mtd-user.h
# tools/install.sh -D -m 644 arm64/include/mtd/nftl-user.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/mtd/nftl-user.h
# tools/install.sh -D -m 644 arm64/include/mtd/ubi-user.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/mtd/ubi-user.h
# tools/install.sh -D -m 644 arm64/include/rdma/bnxt_re-abi.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/rdma/bnxt_re-abi.h
# tools/install.sh -D -m 644 arm64/include/rdma/cxgb3-abi.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/rdma/cxgb3-abi.h
# tools/install.sh -D -m 644 arm64/include/rdma/cxgb4-abi.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/rdma/cxgb4-abi.h
# tools/install.sh -D -m 644 arm64/include/rdma/hfi/hfi1_ioctl.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/rdma/hfi/hfi1_ioctl.h
# tools/install.sh -D -m 644 arm64/include/rdma/hfi/hfi1_user.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/rdma/hfi/hfi1_user.h
# tools/install.sh -D -m 644 arm64/include/rdma/hns-abi.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/rdma/hns-abi.h
# tools/install.sh -D -m 644 arm64/include/rdma/i40iw-abi.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/rdma/i40iw-abi.h
# tools/install.sh -D -m 644 arm64/include/rdma/ib_user_cm.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/rdma/ib_user_cm.h
# tools/install.sh -D -m 644 arm64/include/rdma/ib_user_ioctl_cmds.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/rdma/ib_user_ioctl_cmds.h
# tools/install.sh -D -m 644 arm64/include/rdma/ib_user_ioctl_verbs.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/rdma/ib_user_ioctl_verbs.h
# tools/install.sh -D -m 644 arm64/include/rdma/ib_user_mad.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/rdma/ib_user_mad.h
# tools/install.sh -D -m 644 arm64/include/rdma/ib_user_sa.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/rdma/ib_user_sa.h
# tools/install.sh -D -m 644 arm64/include/rdma/ib_user_verbs.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/rdma/ib_user_verbs.h
# tools/install.sh -D -m 644 arm64/include/rdma/mlx4-abi.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/rdma/mlx4-abi.h
# tools/install.sh -D -m 644 arm64/include/rdma/mlx5-abi.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/rdma/mlx5-abi.h
# tools/install.sh -D -m 644 arm64/include/rdma/mlx5_user_ioctl_cmds.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/rdma/mlx5_user_ioctl_cmds.h
# tools/install.sh -D -m 644 arm64/include/rdma/mlx5_user_ioctl_verbs.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/rdma/mlx5_user_ioctl_verbs.h
# tools/install.sh -D -m 644 arm64/include/rdma/mthca-abi.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/rdma/mthca-abi.h
# tools/install.sh -D -m 644 arm64/include/rdma/nes-abi.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/rdma/nes-abi.h
# tools/install.sh -D -m 644 arm64/include/rdma/ocrdma-abi.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/rdma/ocrdma-abi.h
# tools/install.sh -D -m 644 arm64/include/rdma/qedr-abi.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/rdma/qedr-abi.h
# tools/install.sh -D -m 644 arm64/include/rdma/rdma_netlink.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/rdma/rdma_netlink.h
# tools/install.sh -D -m 644 arm64/include/rdma/rdma_user_cm.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/rdma/rdma_user_cm.h
# tools/install.sh -D -m 644 arm64/include/rdma/rdma_user_ioctl.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/rdma/rdma_user_ioctl.h
# tools/install.sh -D -m 644 arm64/include/rdma/rdma_user_ioctl_cmds.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/rdma/rdma_user_ioctl_cmds.h
# tools/install.sh -D -m 644 arm64/include/rdma/rdma_user_rxe.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/rdma/rdma_user_rxe.h
# tools/install.sh -D -m 644 arm64/include/rdma/vmw_pvrdma-abi.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/rdma/vmw_pvrdma-abi.h
# tools/install.sh -D -m 644 arm64/include/scsi/cxlflash_ioctl.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/scsi/cxlflash_ioctl.h
# tools/install.sh -D -m 644 arm64/include/scsi/fc/fc_els.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/scsi/fc/fc_els.h
# tools/install.sh -D -m 644 arm64/include/scsi/fc/fc_fs.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/scsi/fc/fc_fs.h
# tools/install.sh -D -m 644 arm64/include/scsi/fc/fc_gs.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/scsi/fc/fc_gs.h
# tools/install.sh -D -m 644 arm64/include/scsi/fc/fc_ns.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/scsi/fc/fc_ns.h
# tools/install.sh -D -m 644 arm64/include/scsi/scsi_bsg_fc.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/scsi/scsi_bsg_fc.h
# tools/install.sh -D -m 644 arm64/include/scsi/scsi_netlink.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/scsi/scsi_netlink.h
# tools/install.sh -D -m 644 arm64/include/scsi/scsi_netlink_fc.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/scsi/scsi_netlink_fc.h
# tools/install.sh -D -m 644 arm64/include/sound/asequencer.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/sound/asequencer.h
# tools/install.sh -D -m 644 arm64/include/sound/asoc.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/sound/asoc.h
# tools/install.sh -D -m 644 arm64/include/sound/asound.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/sound/asound.h
# tools/install.sh -D -m 644 arm64/include/sound/asound_fm.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/sound/asound_fm.h
# tools/install.sh -D -m 644 arm64/include/sound/compress_offload.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/sound/compress_offload.h
# tools/install.sh -D -m 644 arm64/include/sound/compress_params.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/sound/compress_params.h
# tools/install.sh -D -m 644 arm64/include/sound/emu10k1.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/sound/emu10k1.h
# tools/install.sh -D -m 644 arm64/include/sound/firewire.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/sound/firewire.h
# tools/install.sh -D -m 644 arm64/include/sound/hdsp.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/sound/hdsp.h
# tools/install.sh -D -m 644 arm64/include/sound/hdspm.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/sound/hdspm.h
# tools/install.sh -D -m 644 arm64/include/sound/sb16_csp.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/sound/sb16_csp.h
# tools/install.sh -D -m 644 arm64/include/sound/sfnt_info.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/sound/sfnt_info.h
# tools/install.sh -D -m 644 arm64/include/sound/skl-tplg-interface.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/sound/skl-tplg-interface.h
# tools/install.sh -D -m 644 arm64/include/sound/snd_sst_tokens.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/sound/snd_sst_tokens.h
# tools/install.sh -D -m 644 arm64/include/sound/tlv.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/sound/tlv.h
# tools/install.sh -D -m 644 arm64/include/sound/usb_stream.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/sound/usb_stream.h
# tools/install.sh -D -m 644 arm64/include/video/edid.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/video/edid.h
# tools/install.sh -D -m 644 arm64/include/video/sisfb.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/video/sisfb.h
# tools/install.sh -D -m 644 arm64/include/video/uvesafb.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/video/uvesafb.h
# tools/install.sh -D -m 644 arm64/include/xen/evtchn.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/xen/evtchn.h
# tools/install.sh -D -m 644 arm64/include/xen/gntalloc.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/xen/gntalloc.h
# tools/install.sh -D -m 644 arm64/include/xen/gntdev.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/xen/gntdev.h
# tools/install.sh -D -m 644 arm64/include/xen/privcmd.h /content/musl-cross-make/build/local/aarch64-linux-musl/obj_kernel_headers/staged/include/xen/privcmd.h
# make[2]: Leaving directory '/content/musl-cross-make/linux-headers-4.19.88'
# find obj_kernel_headers/staged/include '(' -name .install -o -name ..install.cmd ')' -exec rm {} +
# touch obj_kernel_headers/.lc_built
# mkdir -p /usr/local/aarch64-linux-musl/include
# cp -R obj_kernel_headers/staged/include/* /usr/local/aarch64-linux-musl/include
# make[1]: Leaving directory '/content/musl-cross-make/build/local/aarch64-linux-musl'

# %% [markdown]
# #clone repo from TukangM/php-build-scripts-auto (also can use from pmmp repo https://github.com/pmmp/php-build-scripts)
# # #%cd php-build-scripts
#   !! remove hashtag if you used pmmp repo!!
# # #%cd php-build-scripts
#    !! change php-build-scrips-auto to php-build-scripts if you use pmmp source

# %%
# %cd ..
#clone repo from TukangM/php-build-scripts-auto (also can use from pmmp repo https://github.com/pmmp/php-build-scripts)
# !git clone https://github.com/TukangM/php-build-scripts-auto
#%cd php-build-scripts #!! remove hashtag if you used pmmp repo!!
# %cd php-build-scripts-auto 
#%cd php-build-scripts  #change php-build-scrips-auto to php-build-scripts if you use pmmp source
# Out:
# /content
# Cloning into 'php-build-scripts-auto'...
# remote: Enumerating objects: 3085, done.
# remote: Counting objects: 100% (534/534), done.
# remote: Compressing objects: 100% (269/269), done.
# remote: Total 3085 (delta 341), reused 425 (delta 247), pack-reused 2551
# Receiving objects: 100% (3085/3085), 857.11 KiB | 2.96 MiB/s, done.
# Resolving deltas: 100% (2046/2046), done.
# /content/php-build-scripts-auto

# %% [markdown]
# #compile php8 and wait

# %%
#compile php8 and wait
# !./compile.sh -t android-aarch64 -x -f
# Out:
# [PocketMine] PHP compiler for Linux, MacOS and Android
# [INFO] Checking dependencies
# [opt] Set target to android-aarch64
# [opt] Doing cross-compile
# [opt] Enabling abusive optimizations...
# [INFO] Cross-compiling for Android ARMv8 (aarch64)
# [warning] OPcache cannot be used on static builds; this may have a negative effect on performance
# [warning] Xdebug cannot be built in static mode
# [WARNING] Only 1 thread is used by default. Increase thread count using -j (e.g. -j 4) to compile faster.
# [PHP] downloading 8.0.26... done!
# [zlib] downloading 1.2.13... checking... compiling... installing... done!
# [GMP] downloading 6.2.1... checking... compiling... installing... done!
# [OpenSSL] downloading 1.1.1s... checking... compiling... installing... done!
# [cURL] downloading curl-7_86_0... checking... compiling... installing... done!
# [YAML] downloading 0.2.5... checking... compiling... installing... done!
# [LevelDB] downloading 1c7564468b41610da4f498430e795ca4de0931ff... checking... compiling... installing... done!
# [libxml] downloading 2.10.1... checking... compiling... installing... done!
# [libzip] downloading 1.9.2... checking... compiling... installing... done!
# [sqlite3] downloading 3400000... checking... compiling... installing... done!
# [libdeflate] downloading 0d1779a071bcc636e5156ddb7538434da7acad22... compiling... manually copying installation files for static build... done!
# [PHP] Downloading additional extensions...
#   pthreads: downloading 4.1.4... done!
#   yaml: downloading 2.2.2... done!
#   igbinary: downloading 3.2.12... done!
#   recursionguard: downloading 0.1.0... done!
#   crypto: downloading 0.3.2... done!
#   leveldb: downloading 317fdcd8415e1566fc2835ce2bdb8e19b890f9f3... done!
#   chunkutils2: downloading 0.3.3... done!
#   libdeflate: downloading 0.1.0... done!
#   morton: downloading 0.1.2... done!
#   xxhash: downloading 0.1.1... done!
# [PHP] enabling optimizations... checking... compiling... installing... generating php.ini... done!
# [INFO] Cleaning up... done!
# [PocketMine] You should start the server now using "./start.sh".
# [PocketMine] If it doesn't work, please send the "install.log" file to the Bug Tracker.

# %%
#Zipping the reslut
# !ls
# !zip -r php-compiled-for-Linux_arm64.zip bin/
# Out:
# auto-script   install.log				tests
# bin	      php-auto-build-scripts.ipynb		windows-compile-vs.bat
# compile.sh    php-auto-build-scripts-Linux_arm64.ipynb
# install_data  README.md
#   adding: bin/ (stored 0%)
#   adding: bin/php7/ (stored 0%)
#   adding: bin/php7/share/ (stored 0%)
#   adding: bin/php7/share/gtk-doc/ (stored 0%)
#   adding: bin/php7/share/gtk-doc/html/ (stored 0%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/ (stored 0%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/libxml2-xmlexports.html (deflated 72%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/libxml2-xmlunicode.html (deflated 94%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/libxml2-parserInternals.html (deflated 86%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/up.png (stored 0%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/libxml2-uri.html (deflated 82%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/libxml2-HTMLtree.html (deflated 88%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/libxml2-nanoftp.html (deflated 85%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/style.css (deflated 58%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/left.png (stored 0%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/libxml2-xmlsave.html (deflated 85%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/libxml2-xmlmodule.html (deflated 76%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/libxml2-xlink.html (deflated 86%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/libxml2-xpointer.html (deflated 88%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/home.png (stored 0%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/libxml2-schemasInternals.html (deflated 88%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/libxml2-valid.html (deflated 91%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/libxml2-xpath.html (deflated 87%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/libxml2-parser.html (deflated 89%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/libxml2-xmlversion.html (deflated 84%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/libxml2-schematron.html (deflated 85%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/libxml2-xmlerror.html (deflated 82%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/libxml2-pattern.html (deflated 85%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/libxml2-hash.html (deflated 92%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/libxml2-encoding.html (deflated 85%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/libxml2-xmlschemastypes.html (deflated 89%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/libxml2-xmlschemas.html (deflated 88%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/libxml2-tree.html (deflated 89%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/general.html (deflated 69%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/libxml2.devhelp2 (deflated 91%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/libxml2-xmlreader.html (deflated 91%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/libxml2-nanohttp.html (deflated 85%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/libxml2-SAX.html (deflated 89%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/libxml2-xinclude.html (deflated 86%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/libxml2-xmlwriter.html (deflated 95%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/libxml2-threads.html (deflated 81%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/libxml2-globals.html (deflated 89%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/libxml2-c14n.html (deflated 84%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/libxml2-xmlstring.html (deflated 89%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/libxml2-catalog.html (deflated 88%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/libxml2-list.html (deflated 88%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/libxml2-xmlregexp.html (deflated 88%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/libxml2-xmlmemory.html (deflated 87%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/libxml2-SAX2.html (deflated 89%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/index.html (deflated 61%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/libxml2-HTMLparser.html (deflated 88%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/libxml2-xmlIO.html (deflated 89%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/libxml2-entities.html (deflated 87%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/libxml2-relaxng.html (deflated 88%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/libxml2-xpathInternals.html (deflated 91%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/libxml2-xmlautomata.html (deflated 92%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/libxml2-debugXML.html (deflated 89%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/libxml2-chvalid.html (deflated 88%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/libxml2-dict.html (deflated 83%)
#   adding: bin/php7/share/gtk-doc/html/libxml2/right.png (stored 0%)
#   adding: bin/php7/share/info/ (stored 0%)
#   adding: bin/php7/share/info/gmp.info-1 (deflated 72%)
#   adding: bin/php7/share/info/gmp.info (deflated 60%)
#   adding: bin/php7/share/info/gmp.info-2 (deflated 77%)
#   adding: bin/php7/share/doc/ (stored 0%)
#   adding: bin/php7/share/doc/libxml2/ (stored 0%)
#   adding: bin/php7/share/doc/libxml2/xmllint.html (deflated 79%)
#   adding: bin/php7/share/doc/libxml2/tutorial/ (stored 0%)
#   adding: bin/php7/share/doc/libxml2/tutorial/includegetattribute.c (deflated 55%)
#   adding: bin/php7/share/doc/libxml2/tutorial/apf.html (deflated 62%)
#   adding: bin/php7/share/doc/libxml2/tutorial/ar01s07.html (deflated 62%)
#   adding: bin/php7/share/doc/libxml2/tutorial/includeconvert.c (deflated 63%)
#   adding: bin/php7/share/doc/libxml2/tutorial/ape.html (deflated 62%)
#   adding: bin/php7/share/doc/libxml2/tutorial/images/ (stored 0%)
#   adding: bin/php7/share/doc/libxml2/tutorial/images/note.png (deflated 0%)
#   adding: bin/php7/share/doc/libxml2/tutorial/images/up.png (deflated 65%)
#   adding: bin/php7/share/doc/libxml2/tutorial/images/next.png (deflated 61%)
#   adding: bin/php7/share/doc/libxml2/tutorial/images/home.png (deflated 61%)
#   adding: bin/php7/share/doc/libxml2/tutorial/images/toc-blank.png (deflated 11%)
#   adding: bin/php7/share/doc/libxml2/tutorial/images/blank.png (deflated 67%)
#   adding: bin/php7/share/doc/libxml2/tutorial/images/caution.png (deflated 47%)
#   adding: bin/php7/share/doc/libxml2/tutorial/images/draft.png (deflated 4%)
#   adding: bin/php7/share/doc/libxml2/tutorial/images/important.png (stored 0%)
#   adding: bin/php7/share/doc/libxml2/tutorial/images/prev.png (deflated 62%)
#   adding: bin/php7/share/doc/libxml2/tutorial/images/tip.png (deflated 1%)
#   adding: bin/php7/share/doc/libxml2/tutorial/images/callouts/ (stored 0%)
#   adding: bin/php7/share/doc/libxml2/tutorial/images/callouts/3.png (deflated 3%)
#   adding: bin/php7/share/doc/libxml2/tutorial/images/callouts/9.png (deflated 3%)
#   adding: bin/php7/share/doc/libxml2/tutorial/images/callouts/1.png (deflated 4%)
#   adding: bin/php7/share/doc/libxml2/tutorial/images/callouts/2.png (deflated 3%)
#   adding: bin/php7/share/doc/libxml2/tutorial/images/callouts/4.png (deflated 3%)
#   adding: bin/php7/share/doc/libxml2/tutorial/images/callouts/7.png (deflated 3%)
#   adding: bin/php7/share/doc/libxml2/tutorial/images/callouts/10.png (deflated 3%)
#   adding: bin/php7/share/doc/libxml2/tutorial/images/callouts/8.png (deflated 3%)
#   adding: bin/php7/share/doc/libxml2/tutorial/images/callouts/6.png (deflated 3%)
#   adding: bin/php7/share/doc/libxml2/tutorial/images/callouts/5.png (deflated 3%)
#   adding: bin/php7/share/doc/libxml2/tutorial/images/toc-plus.png (deflated 5%)
#   adding: bin/php7/share/doc/libxml2/tutorial/images/warning.png (deflated 47%)
#   adding: bin/php7/share/doc/libxml2/tutorial/images/toc-minus.png (deflated 6%)
#   adding: bin/php7/share/doc/libxml2/tutorial/includexpath.c (deflated 59%)
#   adding: bin/php7/share/doc/libxml2/tutorial/apg.html (deflated 62%)
#   adding: bin/php7/share/doc/libxml2/tutorial/ix01.html (deflated 69%)
#   adding: bin/php7/share/doc/libxml2/tutorial/ar01s02.html (deflated 67%)
#   adding: bin/php7/share/doc/libxml2/tutorial/apb.html (deflated 63%)
#   adding: bin/php7/share/doc/libxml2/tutorial/includeaddkeyword.c (deflated 57%)
#   adding: bin/php7/share/doc/libxml2/tutorial/apa.html (deflated 62%)
#   adding: bin/php7/share/doc/libxml2/tutorial/ar01s04.html (deflated 69%)
#   adding: bin/php7/share/doc/libxml2/tutorial/ar01s06.html (deflated 60%)
#   adding: bin/php7/share/doc/libxml2/tutorial/aph.html (deflated 65%)
#   adding: bin/php7/share/doc/libxml2/tutorial/api.html (deflated 59%)
#   adding: bin/php7/share/doc/libxml2/tutorial/ar01s08.html (deflated 61%)
#   adding: bin/php7/share/doc/libxml2/tutorial/ar01s05.html (deflated 71%)
#   adding: bin/php7/share/doc/libxml2/tutorial/index.html (deflated 69%)
#   adding: bin/php7/share/doc/libxml2/tutorial/includeaddattribute.c (deflated 54%)
#   adding: bin/php7/share/doc/libxml2/tutorial/apd.html (deflated 63%)
#   adding: bin/php7/share/doc/libxml2/tutorial/apc.html (deflated 63%)
#   adding: bin/php7/share/doc/libxml2/tutorial/ar01s03.html (deflated 68%)
#   adding: bin/php7/share/doc/libxml2/tutorial/includekeyword.c (deflated 59%)
#   adding: bin/php7/share/doc/libxml2/tutorial/ar01s09.html (deflated 68%)
#   adding: bin/php7/share/doc/libxml2/xmlcatalog.html (deflated 78%)
#   adding: bin/php7/share/doc/libxml2/examples/ (stored 0%)
#   adding: bin/php7/share/doc/libxml2/examples/reader4.c (deflated 60%)
#   adding: bin/php7/share/doc/libxml2/examples/reader1.c (deflated 58%)
#   adding: bin/php7/share/doc/libxml2/examples/xpath2.c (deflated 62%)
#   adding: bin/php7/share/doc/libxml2/examples/reader2.c (deflated 58%)
#   adding: bin/php7/share/doc/libxml2/examples/testWriter.c (deflated 91%)
#   adding: bin/php7/share/doc/libxml2/examples/parse3.c (deflated 52%)
#   adding: bin/php7/share/doc/libxml2/examples/tree1.c (deflated 53%)
#   adding: bin/php7/share/doc/libxml2/examples/io2.c (deflated 49%)
#   adding: bin/php7/share/doc/libxml2/examples/reader3.c (deflated 59%)
#   adding: bin/php7/share/doc/libxml2/examples/xpath1.c (deflated 68%)
#   adding: bin/php7/share/doc/libxml2/examples/tree2.c (deflated 60%)
#   adding: bin/php7/share/doc/libxml2/examples/xmllint.c (deflated 81%)
#   adding: bin/php7/share/doc/libxml2/examples/index.html (deflated 89%)
#   adding: bin/php7/share/doc/libxml2/examples/parse1.c (deflated 50%)
#   adding: bin/php7/share/doc/libxml2/examples/parse2.c (deflated 57%)
#   adding: bin/php7/share/doc/libxml2/examples/io1.c (deflated 60%)
#   adding: bin/php7/share/doc/libxml2/examples/parse4.c (deflated 60%)
#   adding: bin/php7/share/aclocal/ (stored 0%)
#   adding: bin/php7/share/aclocal/libcurl.m4 (deflated 69%)
#   adding: bin/php7/share/aclocal/libxml.m4 (deflated 68%)
#   adding: bin/php7/bin/ (stored 0%)
#   adding: bin/php7/bin/xmlcatalog (deflated 52%)
#   adding: bin/php7/bin/php-config (deflated 68%)
#   adding: bin/php7/bin/php.ini (deflated 32%)
#   adding: bin/php7/bin/php (deflated 67%)
#   adding: bin/php7/bin/xml2-config (deflated 59%)
#   adding: bin/php7/bin/sqlite3 (deflated 45%)
#   adding: bin/php7/bin/xmllint (deflated 52%)
#   adding: bin/php7/bin/phpize (deflated 66%)
#   adding: bin/php7/lib/ (stored 0%)
#   adding: bin/php7/lib/cmake/ (stored 0%)
#   adding: bin/php7/lib/cmake/leveldb/ (stored 0%)
#   adding: bin/php7/lib/cmake/leveldb/leveldbTargets-release.cmake (deflated 58%)
#   adding: bin/php7/lib/cmake/leveldb/leveldbConfigVersion.cmake (deflated 68%)
#   adding: bin/php7/lib/cmake/leveldb/leveldbConfig.cmake (deflated 49%)
#   adding: bin/php7/lib/cmake/leveldb/leveldbTargets.cmake (deflated 63%)
#   adding: bin/php7/lib/cmake/libxml2/ (stored 0%)
#   adding: bin/php7/lib/cmake/libxml2/libxml2-config.cmake (deflated 73%)
#   adding: bin/php7/lib/cmake/libzip/ (stored 0%)
#   adding: bin/php7/lib/cmake/libzip/libzip-config-version.cmake (deflated 64%)
#   adding: bin/php7/lib/cmake/libzip/libzip-config.cmake (deflated 50%)
#   adding: bin/php7/lib/cmake/libzip/libzip-targets-noconfig.cmake (deflated 56%)
#   adding: bin/php7/lib/cmake/libzip/libzip-targets.cmake (deflated 63%)
#   adding: bin/php7/lib/php/ (stored 0%)
#   adding: bin/php7/lib/php/build/ (stored 0%)
#   adding: bin/php7/lib/php/build/config.sub (deflated 69%)
#   adding: bin/php7/lib/php/build/libtool.m4 (deflated 77%)
#   adding: bin/php7/lib/php/build/ax_gcc_func_attribute.m4 (deflated 78%)
#   adding: bin/php7/lib/php/build/ax_check_compile_flag.m4 (deflated 53%)
#   adding: bin/php7/lib/php/build/gen_stub.php (deflated 81%)
#   adding: bin/php7/lib/php/build/ltmain.sh (deflated 75%)
#   adding: bin/php7/lib/php/build/Makefile.global (deflated 67%)
#   adding: bin/php7/lib/php/build/shtool (deflated 78%)
#   adding: bin/php7/lib/php/build/config.guess (deflated 70%)
#   adding: bin/php7/lib/php/build/php.m4 (deflated 75%)
#   adding: bin/php7/lib/php/build/run-tests.php (deflated 77%)
#   adding: bin/php7/lib/php/build/phpize.m4 (deflated 62%)
#   adding: bin/php7/lib/php/build/pkg.m4 (deflated 66%)
#   adding: bin/php7/lib/php/build/php_cxx_compile_stdcxx.m4 (deflated 71%)
#   adding: bin/php7/lib/engines-1.1/ (stored 0%)
#   adding: bin/php7/lib/pkgconfig/ (stored 0%)
#   adding: bin/php7/lib/pkgconfig/zlib.pc (deflated 38%)
#   adding: bin/php7/lib/pkgconfig/libzip.pc (deflated 37%)
#   adding: bin/php7/lib/pkgconfig/libcurl.pc (deflated 50%)
#   adding: bin/php7/lib/pkgconfig/libcrypto.pc (deflated 37%)
#   adding: bin/php7/lib/pkgconfig/yaml-0.1.pc (deflated 31%)
#   adding: bin/php7/lib/pkgconfig/libxml-2.0.pc (deflated 39%)
#   adding: bin/php7/lib/pkgconfig/libssl.pc (deflated 31%)
#   adding: bin/php7/lib/pkgconfig/openssl.pc (deflated 31%)
#   adding: bin/php7/lib/pkgconfig/gmp.pc (deflated 30%)
#   adding: bin/php7/lib/pkgconfig/sqlite3.pc (deflated 31%)

# %% [markdown]
# #Download the Result (Dont use firefox. use Chromium based browser like Google Chrome, MS Egde, Opera, Brave)

# %%
#Download the result
from google.colab import files
files.download('php-compiled-for-Linux_arm64.zip')

# %% [markdown]
# downlaod php-compiled-for-Linux_arm64.zip with transfer.sh

# %%
# !curl --upload-file ./php-compiled-for-Linux_arm64.zip https://transfer.sh/php-compiled-for-Linux_arm64.zip
# Out:
# https://transfer.sh/4M0LOl/php-compiled-for-Linux_arm64.zip

# %% [markdown]
# #Voila!!
# you builded php8 for arm64!!
